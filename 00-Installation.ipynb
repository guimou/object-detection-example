# %%
# !pip install --no-cache-dir -r requirements.txt
# !pip uninstall -y opencv-python
# !pip uninstall -y opencv-python-headless
# !pip install opencv-python-headless==4.8.1.78
# Out:
# Collecting onnx==1.14.0
#   Downloading onnx-1.14.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 149.4 MB/s eta 0:00:00a 0:00:01
# Collecting onnxruntime-gpu==1.14.0
#   Downloading onnxruntime_gpu-1.14.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (136.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.1/136.1 MB 180.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: openimages==0.0.1 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.0.1)
# Requirement already satisfied: ultralytics==8.0.130 in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (8.0.130)
# Collecting seaborn==0.12.2
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 305.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /opt/app-root/lib/python3.9/site-packages (from onnx==1.14.0->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /opt/app-root/lib/python3.9/site-packages (from onnx==1.14.0->-r requirements.txt (line 1)) (4.11.0)
# Requirement already satisfied: protobuf>=3.20.2 in /opt/app-root/lib/python3.9/site-packages (from onnx==1.14.0->-r requirements.txt (line 1)) (4.25.3)
# Requirement already satisfied: flatbuffers in /opt/app-root/lib/python3.9/site-packages (from onnxruntime-gpu==1.14.0->-r requirements.txt (line 2)) (24.3.25)
# Requirement already satisfied: packaging in /opt/app-root/lib/python3.9/site-packages (from onnxruntime-gpu==1.14.0->-r requirements.txt (line 2)) (24.0)
# Requirement already satisfied: sympy in /opt/app-root/lib/python3.9/site-packages (from onnxruntime-gpu==1.14.0->-r requirements.txt (line 2)) (1.12)
# Requirement already satisfied: coloredlogs in /opt/app-root/lib/python3.9/site-packages (from onnxruntime-gpu==1.14.0->-r requirements.txt (line 2)) (15.0.1)
# Requirement already satisfied: requests in /opt/app-root/lib/python3.9/site-packages (from openimages==0.0.1->-r requirements.txt (line 3)) (2.32.2)
# Requirement already satisfied: boto3 in /opt/app-root/lib/python3.9/site-packages (from openimages==0.0.1->-r requirements.txt (line 3)) (1.34.111)
# Requirement already satisfied: lxml in /opt/app-root/lib/python3.9/site-packages (from openimages==0.0.1->-r requirements.txt (line 3)) (5.2.2)
# Requirement already satisfied: pandas in /opt/app-root/lib/python3.9/site-packages (from openimages==0.0.1->-r requirements.txt (line 3)) (2.2.2)
# Requirement already satisfied: cvdata in /opt/app-root/lib/python3.9/site-packages (from openimages==0.0.1->-r requirements.txt (line 3)) (0.0.3)
# Requirement already satisfied: tqdm in /opt/app-root/lib/python3.9/site-packages (from openimages==0.0.1->-r requirements.txt (line 3)) (4.66.4)
# Requirement already satisfied: scipy>=1.4.1 in /opt/app-root/lib/python3.9/site-packages (from ultralytics==8.0.130->-r requirements.txt (line 4)) (1.12.0)
# Requirement already satisfied: torchvision>=0.8.1 in /opt/app-root/lib/python3.9/site-packages (from ultralytics==8.0.130->-r requirements.txt (line 4)) (0.17.2+cu121)
# Collecting opencv-python>=4.6.0
#   Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 221.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: Pillow>=7.1.2 in /opt/app-root/lib/python3.9/site-packages (from ultralytics==8.0.130->-r requirements.txt (line 4)) (10.3.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/app-root/lib/python3.9/site-packages (from ultralytics==8.0.130->-r requirements.txt (line 4)) (6.0.1)
# Requirement already satisfied: psutil in /opt/app-root/lib/python3.9/site-packages (from ultralytics==8.0.130->-r requirements.txt (line 4)) (5.9.8)
# Requirement already satisfied: torch>=1.7.0 in /opt/app-root/lib/python3.9/site-packages (from ultralytics==8.0.130->-r requirements.txt (line 4)) (2.2.2+cu121)
# Requirement already satisfied: matplotlib>=3.2.2 in /opt/app-root/lib/python3.9/site-packages (from ultralytics==8.0.130->-r requirements.txt (line 4)) (3.8.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/app-root/lib/python3.9/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.130->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/app-root/lib/python3.9/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.130->-r requirements.txt (line 4)) (6.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/app-root/lib/python3.9/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.130->-r requirements.txt (line 4)) (4.51.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/app-root/lib/python3.9/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.130->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/app-root/lib/python3.9/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.130->-r requirements.txt (line 4)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/app-root/lib/python3.9/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.130->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/app-root/lib/python3.9/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.130->-r requirements.txt (line 4)) (1.4.5)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.9/site-packages (from pandas->openimages==0.0.1->-r requirements.txt (line 3)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/app-root/lib/python3.9/site-packages (from pandas->openimages==0.0.1->-r requirements.txt (line 3)) (2024.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.9/site-packages (from requests->openimages==0.0.1->-r requirements.txt (line 3)) (2024.2.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/app-root/lib/python3.9/site-packages (from requests->openimages==0.0.1->-r requirements.txt (line 3)) (1.26.18)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.9/site-packages (from requests->openimages==0.0.1->-r requirements.txt (line 3)) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/app-root/lib/python3.9/site-packages (from requests->openimages==0.0.1->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.7.0->ultralytics==8.0.130->-r requirements.txt (line 4)) (12.1.0.106)
# Requirement already satisfied: fsspec in /opt/app-root/lib/python3.9/site-packages (from torch>=1.7.0->ultralytics==8.0.130->-r requirements.txt (line 4)) (2024.5.0)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.7.0->ultralytics==8.0.130->-r requirements.txt (line 4)) (2.19.3)
# Requirement already satisfied: triton==2.2.0 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.7.0->ultralytics==8.0.130->-r requirements.txt (line 4)) (2.2.0)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.7.0->ultralytics==8.0.130->-r requirements.txt (line 4)) (12.1.105)
# Requirement already satisfied: networkx in /opt/app-root/lib/python3.9/site-packages (from torch>=1.7.0->ultralytics==8.0.130->-r requirements.txt (line 4)) (3.2.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.7.0->ultralytics==8.0.130->-r requirements.txt (line 4)) (11.0.2.54)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.7.0->ultralytics==8.0.130->-r requirements.txt (line 4)) (11.4.5.107)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.7.0->ultralytics==8.0.130->-r requirements.txt (line 4)) (12.1.105)
# Requirement already satisfied: jinja2 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.7.0->ultralytics==8.0.130->-r requirements.txt (line 4)) (3.1.4)
# Requirement already satisfied: filelock in /opt/app-root/lib/python3.9/site-packages (from torch>=1.7.0->ultralytics==8.0.130->-r requirements.txt (line 4)) (3.14.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.7.0->ultralytics==8.0.130->-r requirements.txt (line 4)) (12.1.3.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.7.0->ultralytics==8.0.130->-r requirements.txt (line 4)) (10.3.2.106)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.7.0->ultralytics==8.0.130->-r requirements.txt (line 4)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.7.0->ultralytics==8.0.130->-r requirements.txt (line 4)) (8.9.2.26)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.7.0->ultralytics==8.0.130->-r requirements.txt (line 4)) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/app-root/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.7.0->ultralytics==8.0.130->-r requirements.txt (line 4)) (12.5.40)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /opt/app-root/lib/python3.9/site-packages (from boto3->openimages==0.0.1->-r requirements.txt (line 3)) (0.10.1)
# Requirement already satisfied: botocore<1.35.0,>=1.34.111 in /opt/app-root/lib/python3.9/site-packages (from boto3->openimages==0.0.1->-r requirements.txt (line 3)) (1.34.111)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/app-root/lib/python3.9/site-packages (from boto3->openimages==0.0.1->-r requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/app-root/lib/python3.9/site-packages (from coloredlogs->onnxruntime-gpu==1.14.0->-r requirements.txt (line 2)) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/app-root/lib/python3.9/site-packages (from sympy->onnxruntime-gpu==1.14.0->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: zipp>=3.1.0 in /opt/app-root/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.2.2->ultralytics==8.0.130->-r requirements.txt (line 4)) (3.18.2)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->ultralytics==8.0.130->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/app-root/lib/python3.9/site-packages (from jinja2->torch>=1.7.0->ultralytics==8.0.130->-r requirements.txt (line 4)) (2.1.5)
# Installing collected packages: opencv-python, onnx, onnxruntime-gpu, seaborn
#   Attempting uninstall: onnx
#     Found existing installation: onnx 1.16.1
#     Uninstalling onnx-1.16.1:
#       Successfully uninstalled onnx-1.16.1
#   Attempting uninstall: onnxruntime-gpu
#     Found existing installation: onnxruntime-gpu 1.18.1
#     Uninstalling onnxruntime-gpu-1.18.1:
#       Successfully uninstalled onnxruntime-gpu-1.18.1
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.13.2
#     Uninstalling seaborn-0.13.2:
#       Successfully uninstalled seaborn-0.13.2
# Successfully installed onnx-1.14.0 onnxruntime-gpu-1.14.0 opencv-python-4.10.0.84 seaborn-0.12.2
#
# [notice] A new release of pip available: 22.2.2 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Found existing installation: opencv-python 4.10.0.84
# Uninstalling opencv-python-4.10.0.84:
#   Successfully uninstalled opencv-python-4.10.0.84
# Found existing installation: opencv-python-headless 4.8.1.78
# Uninstalling opencv-python-headless-4.8.1.78:
#   Successfully uninstalled opencv-python-headless-4.8.1.78
# Collecting opencv-python-headless==4.8.1.78
#   Downloading opencv_python_headless-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 279.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.17.0 in /opt/app-root/lib/python3.9/site-packages (from opencv-python-headless==4.8.1.78) (1.26.4)
# Installing collected packages: opencv-python-headless
# Successfully installed opencv-python-headless-4.8.1.78
#
# [notice] A new release of pip available: 22.2.2 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
